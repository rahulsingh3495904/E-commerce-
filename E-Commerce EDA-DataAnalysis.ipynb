# %%
#importing things
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
import datetime

# %%
# reading files
rider_provider='Ecommerce - UK Retailer.csv'
ecom=pd.read_csv(rider_provider, encoding = 'ISO-8859-1')

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
'''task 1 !---------------------------------------------------------------------------------------------------------'''
# Out:
# 'task 1 !---------------------------------------------------------------------------------------------------------'

# %%
#checking the datatypes for uses
ecom.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
'''so accourding to the analysis there is just 'quantity' column which is in integer datatype but i will be using the float datatypes too for better analysis'''
# Out:
# "so accourding to the analysis there is just 'quantity' column which is in integer datatype but i will be using the float datatypes too for better analysis"

# %%
# part a> PLOTING BOX PLOT FOR QUANTITY COLUMN
sns.set()
plt.boxplot(ecom.Quantity)
plt.show()
plt.boxplot(ecom.UnitPrice)
plt.show()

# %%
#part b> plotting histogram for integer values
sns.set()
ecom.hist(color='#86bf91',figsize=(15,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000213D0042E88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000213D1082DC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000213D10BBAC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000213D10F4C08>]],
#       dtype=object)

# %%
#part c> plotting Distribution Plot of All Numeric Variables

# %%
sns.set
sns.distplot(ecom['CustomerID'])
plt.show()
sns.distplot(ecom['Quantity'])
plt.show()
sns.distplot(ecom['UnitPrice'])
plt.show()

# %%
#hdd=ecom.groupby('')

# %%
'''Task 2------------------------------------------------------------------------------------'''
# Out:
# 'Task 2------------------------------------------------------------------------------------'

# %%
#checking the missing values in dataset
print('The values which are missing in  E-commerce dataset are :-\n{}'.format(ecom.isnull().sum()))
# Out:
# The values which are missing in  E-commerce dataset are :-
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
'''the description and customer id are the columns with missing values and to deal with ot we need more information of the dataset thus:-

'''
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
'''thus from the analysis we need to replace the missing value of the description column with the mode is having a non numerical value and mode best and only suitable Statistcal method to do so'''
ecom.Description.fillna(ecom.Description.mode()[0],inplace = False)
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
'''since the CustomerID column is having a numeric data type i.e float64 thus the median will be best to replace with the missing values'''
ecom.CustomerID.fillna(ecom.CustomerID.median(),inplace=False)
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 541909, dtype: float64

# %%
#checking the status of changes made
print('The values which are missing in  E-commerce dataset  are :-\n{}'.format(ecom.isnull().sum()))
# Out:
# The values which are missing in  E-commerce dataset  are :-
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
'''---------------------------TASK 3-------------------------------------------------------------------------------------------------'''
# Out:
# '---------------------------TASK 3-------------------------------------------------------------------------------------------------'

# %%
#checking the availablity of dublicate rows in the dataset
ecom.duplicated().sum()
# Out:
# 5268

# %%
print("thus the dublicate values are:-")
ecom.loc[ecom.duplicated(),:]
# Out:
# thus the dublicate values are:-
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 517     12/1/2010 11:45       1.25     17908.0  United Kingdom
# 527     12/1/2010 11:45       2.10     17908.0  United Kingdom
# 537     12/1/2010 11:45       2.95     17908.0  United Kingdom
# 539     12/1/2010 11:45       4.95     17908.0  United Kingdom
# 555     12/1/2010 11:49       2.95     17920.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541675  12/9/2011 11:34       0.39     14446.0  United Kingdom
# 541689  12/9/2011 11:34       2.49     14446.0  United Kingdom
# 541692  12/9/2011 11:34       1.95     14446.0  United Kingdom
# 541699  12/9/2011 11:34       2.10     14446.0  United Kingdom
# 541701  12/9/2011 11:34       2.08     14446.0  United Kingdom
#
# [5268 rows x 8 columns]

# %%
#deleting the dublicate rows keeping the first one which is the original one 
ecom.drop_duplicates(subset=None, keep='first',inplace=True)

# %%
#checking the status of removal of dublicate rows
ecom.duplicated().sum()
# Out:
# 0

# %%
# checking the count of the dataset before removing the negative values
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  536641.000000  536641.000000  401604.000000
# mean        9.620029       4.632656   15281.160818
# std       219.130156      97.233118    1714.006089
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13939.000000
# 50%         3.000000       2.080000   15145.000000
# 75%        10.000000       4.130000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
ecom = ecom[ecom.Quantity > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f9ec641ceac> in <module>
# ----> 1 ecom = ecom[ecom.Quantity > 0]
#
# NameError: name 'ecom' is not defined

# %%
# checking the count of the dataset to confirm the removal of negative values if any:
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  526054.000000  526054.000000  392732.000000
# mean       10.730874       3.871747   15287.734822
# std       157.591838      42.016560    1713.567773
# min         1.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13955.000000
# 50%         4.000000       2.080000   15150.000000
# 75%        11.000000       4.130000   16791.000000
# max     80995.000000   13541.330000   18287.000000

# %%
'''---------------------task 5-------------------------------------------------------------------------'''
# Out:
# '---------------------task 5-------------------------------------------------------------------------'

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#converting the string column to date datatypes....
ecom.InvoiceDate=pd.to_datetime(ecom.InvoiceDate)

# %%
''' adding month day and hour columns with the data which i mapped through InvoiceDate column to take in the data'''
ecom.insert(loc=1, column='Year_Month', value=ecom.InvoiceDate.map(lambda x: 100*x.year + x.month))
ecom.insert(loc=2, column='Month', value=ecom.InvoiceDate.dt.month)
# considering +1 to make it monday as we start our week from Monday and thus sunday will be taken as 7....
ecom.insert(loc=3, column='day', value=(ecom.InvoiceDate.dt.dayofweek)+1)
ecom.insert(loc=4, column='hour', value=ecom.InvoiceDate.dt.hour)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-b3367283a1a4> in <module>
#       1 ''' adding month day and hour columns with the data which i mapped through InvoiceDate column to take in the data'''
# ----> 2 ecom.insert(loc=1, column='Year_Month', value=ecom.InvoiceDate.map(lambda x: 100*x.year + x.month))
#       3 ecom.insert(loc=2, column='Month', value=ecom.InvoiceDate.dt.month)
#       4 # considering +1 to make it monday as we start our week from Monday and thus sunday will be taken as 7....
#       5 ecom.insert(loc=3, column='day', value=(ecom.InvoiceDate.dt.dayofweek)+1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3761         self._ensure_valid_index(value)
#    3762         value = self._sanitize_column(column, value, broadcast=False)
# -> 3763         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3764
#    3765     def assign(self, **kwargs) -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1189         if not allow_duplicates and item in self.items:
#    1190             # Should this be a different kind of error??
# -> 1191             raise ValueError(f"cannot insert {item}, already exists")
#    1192
#    1193         if not isinstance(loc, int):
#
# ValueError: cannot insert Year_Month, already exists

# %%
'''checking the changes made'''
ecom
# Out:
#        InvoiceNo  Year_Month  Month  day  hour StockCode  \
# 0         536365      201012     12    3     8    85123A
# 1         536365      201012     12    3     8     71053
# 2         536365      201012     12    3     8    84406B
# 3         536365      201012     12    3     8    84029G
# 4         536365      201012     12    3     8    84029E
# ...          ...         ...    ...  ...   ...       ...
# 541904    581587      201112     12    5    12     22613
# 541905    581587      201112     12    5    12     22899
# 541906    581587      201112     12    5    12     23254
# 541907    581587      201112     12    5    12     23255
# 541908    581587      201112     12    5    12     22138
#
#                                 Description  Quantity         InvoiceDate  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                       WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2            CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3       KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4            RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
# ...                                     ...       ...                 ...
# 541904          PACK OF 20 SPACEBOY NAPKINS        12 2011-12-09 12:50:00
# 541905         CHILDREN'S APRON DOLLY GIRL          6 2011-12-09 12:50:00
# 541906        CHILDRENS CUTLERY DOLLY GIRL          4 2011-12-09 12:50:00
# 541907      CHILDRENS CUTLERY CIRCUS PARADE         4 2011-12-09 12:50:00
# 541908        BAKING SET 9 PIECE RETROSPOT          3 2011-12-09 12:50:00
#
#         UnitPrice  CustomerID         Country
# 0            2.55     17850.0  United Kingdom
# 1            3.39     17850.0  United Kingdom
# 2            2.75     17850.0  United Kingdom
# 3            3.39     17850.0  United Kingdom
# 4            3.39     17850.0  United Kingdom
# ...           ...         ...             ...
# 541904       0.85     12680.0          France
# 541905       2.10     12680.0          France
# 541906       4.15     12680.0          France
# 541907       4.15     12680.0          France
# 541908       4.95     12680.0          France
#
# [541909 rows x 12 columns]

# %%
'''task 6 --------------------------------------------------------------------------------------------------------------------------------------'''
# Out:
# 'task 6 --------------------------------------------------------------------------------------------------------------------------------------'

# %%
#groupig the customer id and their invoice to exmamin the order made by the customers
ecom.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count().head()
# Out:
#    CustomerID         Country  InvoiceNo
# 0     12346.0  United Kingdom          2
# 1     12347.0         Iceland        182
# 2     12348.0         Finland         31
# 3     12349.0           Italy         73
# 4     12350.0          Norway         17

# %%
sns.set()
orders = ecom.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()

plt.subplots(figsize=(15,6))
plt.plot(orders.CustomerID, orders.InvoiceNo)
plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Count of orders for different Customers')
plt.show()

# %%
'''task 7 --------------------------------------------------------------------------------------------------------------------------------------'''
# Out:
# 'task 7 --------------------------------------------------------------------------------------------------------------------------------------'

# %%
print('The TOP 5 customers with max no of orders...')
orders.sort_values(by='InvoiceNo', ascending=False).head()
# Out:
# The TOP 5 customers with max no of orders...
#       CustomerID         Country  InvoiceNo
# 4050     17841.0  United Kingdom       7983
# 1903     14911.0            EIRE       5903
# 1308     14096.0  United Kingdom       5128
# 338      12748.0  United Kingdom       4642
# 1682     14606.0  United Kingdom       2782

# %%
'''task 8 --------------------------------------------------------------------------------------------------------------------------------------'''
# Out:
# 'task 8 --------------------------------------------------------------------------------------------------------------------------------------'

# %%
mkr_gone = ecom.groupby(by=['CustomerID','Country'], as_index=False)['UnitPrice'].sum()

sns.set()
plt.subplots(figsize=(15,6))
plt.plot(mkr_gone.CustomerID, mkr_gone.UnitPrice)
plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')
plt.show()

# %%
'''task 9 --------------------------------------------------------------------------------------------------------------------------------------'''
# Out:
# 'task 9 --------------------------------------------------------------------------------------------------------------------------------------'

# %%
print('The TOP 5 customers with max no of orders...')
mkr_gone.sort_values(by='UnitPrice', ascending=False).head()
# Out:
# The TOP 5 customers with max no of orders...
#       CustomerID         Country  UnitPrice
# 1308     14096.0  United Kingdom   41376.33
# 2035     15098.0  United Kingdom   40278.90
# 1903     14911.0            EIRE   31060.66
# 336      12744.0       Singapore   25108.89
# 2730     16029.0  United Kingdom   24111.14

# %%
ecom.head()#just wanna see the column titles
# Out:
#   InvoiceNo  Year_Month  Month  day  hour StockCode  \
# 0    536365      201012     12    3     8    85123A
# 1    536365      201012     12    3     8     71053
# 2    536365      201012     12    3     8    84406B
# 3    536365      201012     12    3     8    84029G
# 4    536365      201012     12    3     8    84029E
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country
# 0       2.55     17850.0  United Kingdom
# 1       3.39     17850.0  United Kingdom
# 2       2.75     17850.0  United Kingdom
# 3       3.39     17850.0  United Kingdom
# 4       3.39     17850.0  United Kingdom

# %%
sns.set()
ax = ecom.groupby('InvoiceNo')['Year_Month'].unique().value_counts().sort_index()
ax.plot(kind="bar",title="number of orders in month ",fontsize=15)
plt.figsize=(15,6)
plt.xlabel("year_month",fontsize=15)
plt.ylabel("number of orders",fontsize=15)
# Out:
# Text(0, 0.5, 'number of orders')

# %%
sns.set()
pikapika=ecom.groupby('InvoiceNo')['day'].unique().value_counts().sort_index()
pikapika.plot(kind="bar", title="Number of orders per day")
plt.figsize=(15,6)
plt.xlabel('Hour')
plt.ylabel('Number of Orders')
# Out:
# Text(0, 0.5, 'Number of Orders')

# %%
sns.set()
syduck=ecom.groupby('InvoiceNo')['hour'].unique().value_counts().iloc[:-1].sort_index()
syduck.plot(kind="bar",title="Number of orders per hour")
plt.xlabel('Hours')
plt.ylabel('Number of orders')
plt.show()

# %%
'''-------task 13-------------------------------------------------------------------'''
# Out:
# '-------task 13-------------------------------------------------------------------'

# %%
sns.set()
group_country_orders = ecom.groupby('Country')['InvoiceNo'].count().sort_values()

# plot number of unique customers in each country
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh')
plt.xlabel('Number of Orders')
plt.ylabel('Country')
plt.title('Number of Orders for different Countries')
plt.show()

# %%
'''since our dataset is baised on united kingdom thus it is being difficult to analyse the data of other countries as uk is having most of the data and suppressing others so to analyse other country data it will be better to drop it a while '''
# Out:
# 'since our dataset is baised on united kingdom thus it is being difficult to analyse the data of other countries as uk is having most of the data and suppressing others so to analyse other country data it will be better to drop it a while '

# %%
sns.set()
group_country_orders = ecom.groupby('Country')['InvoiceNo'].count().sort_values()
del group_country_orders['United Kingdom']

# plot number of unique customers in each country without uk 
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh',fontsize=12)
plt.xlabel('Number of Orders',fontsize=12)
plt.ylabel('Country',fontsize=12)
plt.title('Number of Orders for different Countries',fontsize=12)
plt.show()

# %%
'''------------------------------------------task 14------------------------------------------------------------'''
# Out:
# '------------------------------------------task 14------------------------------------------------------------'

# %%
sns.set()
ord_mon=ecom.groupby('InvoiceNo')['Month'].unique().value_counts().sort_index()
ord_mon.plot(kind="line",title="trend of order across month",fontsize=15)
plt.xlabel("Month",fontsize=15)
plt.ylabel("Orders",fontsize=15)
# Out:
# Text(0, 0.5, 'Orders')

# %%
'''-------------------task 15----------------------------------------------------'''
# Out:
# '-------------------task 15----------------------------------------------------'

# %%
sns.set()
panda_money = ecom.groupby('Country')['UnitPrice'].sum().sort_values()

# plot number of unique customers in each country
plt.subplots(figsize=(15,8))
panda_money.plot(kind='barh', fontsize=12)
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %% [markdown]
# ## Again the problem arrose that data is baised towards united kingdom thus removing uk will improve the analysis

# %%
panda_money = ecom.groupby('Country')['UnitPrice'].sum().sort_values()
del panda_money['United Kingdom']

# plot number of unique customers in each country
plt.subplots(figsize=(15,8))
panda_money.plot(kind='barh', fontsize=12)
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()
